# %%
import geopandas as gpd
import fiona

# %%
gdb_file = './data/bdgd/UCAT_tab_2022-12-31.gdb'
layers = fiona.listlayers(gdb_file)
layers
# Out:
# ['UCAT_tab']

# %%
gdf = gpd.read_file(gdb_file,layer='UCAT_tab', ignore_geometry=True)

# %%
gdf
# Out:
#           PN_CON  DIST      PAC      CTAT      SUB   CONJ      MUN CEG_GD  \
# 0     1017033690  7019  5942222       302  5003159  13008  1302603
# 1     1018796718  7019  6188702       327  5003144  13008  1302603
# 2     1017033526  7019  5942578       372  5003159  15800  1302603
# 3     1017033444  7019  5747011       314           13011  1302603
# 4     1017032261  7019  5746456       372  5003159  13008  1302603
# ...          ...   ...      ...       ...      ...    ...      ...    ...
# 1933      111187    46  1111871  1_SE69_1     SE69  15602  2802106
# 1934      111186    46  1111861  1_SE69_1     SE69  15602  2802106
# 1935      659918    46  6599181  3_SECH_1     SECH  15602  2802106
# 1936      672748    46  6727481  2_SE69_1     SE69  15602  2802106
# 1937      680318    46  6803181  3_SECH_1     SECH  15602  2802106
#
#                       BRR         CEP  ... FIC_06 FIC_07 FIC_08 FIC_09 FIC_10  \
# ...
